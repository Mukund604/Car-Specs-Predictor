# %%
import pandas as pd
# df = pd.read_excel('/Users/mukund/Documents/GitHub/Eurpoean_Car_Dataset/Dataset/European-Car-Database-by-Teoalida-full-specs-SAMPLE.xlsx')
df = pd.read_excel('C:\\Users\\avaada\\Documents\\GitHub\\Car-Specs-Predictor\\Dataset\\European-Car-Database-by-Teoalida-full-specs-SAMPLE.xlsx')
df.head(20)
# Out:
#     Unnamed: 0                                              Basic Basic.1  \
# 0          NaN                                                  -     NaN
# 1          NaN                                                  -     NaN
# 2          NaN                                      Full car name      ID
# 3          NaN                                               Name   carId
# 4          NaN                                               3667    3667
# 5          NaN                                                  1       1
# 6          NaN                                                NaN     NaN
# 7          NaN                                German Car Database     NaN
# 8          NaN  Compiled in Excel by Teoalida © cardatabase.te...     NaN
# 9          NaN                                                NaN     NaN
# 10         NaN  This file is a SAMPLE, including BMW 3-Series ...     NaN
# 11         NaN  Visit cardatabase.teoalida.com for the FULL da...     NaN
# ...

# %%
cols = df.iloc[2]
# df = pd.read_excel('/Users/mukund/Documents/GitHub/Eurpoean_Car_Dataset/Dataset/European-Car-Database-by-Teoalida-full-specs-SAMPLE.xlsx', names=cols, header=14)
df = pd.read_excel('C:\\Users\\avaada\\Documents\\GitHub\\Car-Specs-Predictor\\Dataset\\European-Car-Database-by-Teoalida-full-specs-SAMPLE.xlsx', names = cols, header = 14)

# %%
cols = df.columns
cols_df = pd.DataFrame(cols)
print(cols)
# cols_df.to_excel('Required_columns.xlsx')
# Out:
# Index([                                    nan,
#                                'Full car name',
#                                           'ID',
#                                   'Source URL',
#                                    'Image URL',
#                                        'Brand',
#                                        'Range',
#                                   'Generation',
#                                 'Model series',
#                   'Manufacturer internal code',
#        ...
#              'Insurance Premium Partial Cover',
#        'Insurance Premium Comprehensive Cover',
#                                 'Costs months',
#                             'Costs kilometers',
#                              'Costs per month',
#                          'Costs per kilometer',
#                          'Costs deterioration',
#                            'Costs operational',
#                                    'Costs fix',
# ...

# %%
required_cols = ['Full car name', 'Brand', 'Generation', 'Model launch date', 'Model end date', 'Fuel type', 'Power (HP)','Torque (system performance)','Number of cylinders (combustion engine)', 'Displacement (ccm)', 'Base price', 'Fuel type.1', 'Gearbox type', 'Number of gears', 'Length (mm)', 'Width (mm)', 'Height (mm)', 'Wheelbase (mm)','Curb weight (kg)', 'Body type', 'Number of doors', 'Acceleration (s)', 'Top speed (km/h)', 'Gas tank size', 'CO2 emissions (NEFZ)']
required_data = df[required_cols]
required_data
# Out:
#                              Full car name   Brand Generation  \
# 0                         BMW 315 (4-Gang)     BMW        E21
# 1                         BMW 315 (5-Gang)     BMW        E21
# 2                         BMW 316 (4-Gang)     BMW        E21
# 3                         BMW 316 (5-Gang)     BMW        E21
# 4                         BMW 316 (4-Gang)     BMW        E21
# ...                                    ...     ...        ...
# 3662    Toyota Prius+ 1.8 Hybrid Executive  Toyota      XW3/4
# 3663    Toyota Prius+ 1.8 Hybrid Executive  Toyota      XW3/4
# 3664             Toyota Prius+ 1.8 Hybrid   Toyota      XW3/4
# 3665         Toyota Prius+ 1.8 Hybrid Life  Toyota      XW3/4
# 3666  Toyota Prius+ 1.8 Hybrid TEC-Edition  Toyota      XW3/4
#
#      Model launch date Model end date   Fuel type  Power (HP)  \
# 0           1981-03-01     1984-06-01  Super Plus          75
# 1           1981-03-01     1984-06-01  Super Plus          75
# ...

# %%
# required_data.to_excel('/Users/mukund/Documents/GitHub/Eurpoean_Car_Dataset/Filtered_Data/Filtered_data.xlsx', index = False)
required_data.to_excel('C:\\Users\\avaada\\Documents\\GitHub\\Car-Specs-Predictor\\Filtered_Data\\Filtered_data.xlsx', index = False)
